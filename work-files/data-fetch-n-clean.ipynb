# %%
# libraries for data manipultion
import pandas as pd
import numpy as np

# libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# finance libraries
import yfinance as yf

# %%
tr_eikon_df = pd.read_csv('../data-files/tr_eikon_eod_data.csv')
tr_eikon_df.index = pd.to_datetime(tr_eikon_df['Date'])
tr_eikon_df = tr_eikon_df[['AAPL.O', 'MSFT.O', 'INTC.O', 'AMZN.O', 'GS.N']].dropna()
# I see some dates where no trading occurs so in this case it seems resonable to dropna()

tr_eikon_df
# Out:
#                 AAPL.O  MSFT.O  INTC.O   AMZN.O    GS.N
# Date
# 2010-01-04   30.572827  30.950   20.88   133.90  173.08
# 2010-01-05   30.625684  30.960   20.87   134.69  176.14
# 2010-01-06   30.138541  30.770   20.80   132.25  174.26
# 2010-01-07   30.082827  30.452   20.60   130.00  177.67
# 2010-01-08   30.282827  30.660   20.83   133.52  174.31
# ...                ...     ...     ...      ...     ...
# 2018-06-25  182.170000  98.390   50.71  1663.15  221.54
# 2018-06-26  184.430000  99.080   49.67  1691.09  221.58
# 2018-06-27  184.160000  97.540   48.76  1660.51  220.18
# 2018-06-28  185.500000  98.630   49.25  1701.45  223.42
# 2018-06-29  185.110000  98.610   49.71  1699.80  220.57
#
# [2138 rows x 5 columns]

# %%
# returns a heatmap on how linearly correlated all features are 

def corr_heatmap(df):
        df.reset_index(drop=True, inplace=True)
        graph_size = (12, 12)
        fig, ax = plt.subplots(figsize=graph_size)
        sns.heatmap(df.corr(), ax=ax, vmin=-1, vmax=1, cmap='coolwarm')

        plt.show()

# %%
corr_heatmap(tr_eikon_df)
