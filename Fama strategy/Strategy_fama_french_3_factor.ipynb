# %%
# libraries for data manipultion
import pandas as pd
import numpy as np

# libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

#ml libraries
from sklearn.linear_model import LinearRegression

#stats lib
import statsmodels.api as sm

# %%
tr_eikon_df = pd.read_csv('tr_eikon_eod_data.csv')
tr_eikon_df.index = pd.to_datetime(tr_eikon_df['Date'])
tr = tr_eikon_df[['AAPL.O', 'MSFT.O', 'INTC.O', 'AMZN.O', 'GS.N']].dropna()
store = tr.copy(deep = True)

#covert returns to PERCENTAGE CHANGE
for col in tr.columns:
    tr['Returns' + " " + col] = tr[col].pct_change() * 100

tr = tr.dropna()
tr
# Out:
#                 AAPL.O  MSFT.O  INTC.O    AMZN.O    GS.N  Returns AAPL.O  \
# Date
# 2010-01-05   30.625684  30.960   20.87   134.690  176.14        0.172889
# 2010-01-06   30.138541  30.770   20.80   132.250  174.26       -1.590633
# 2010-01-07   30.082827  30.452   20.60   130.000  177.67       -0.184860
# 2010-01-08   30.282827  30.660   20.83   133.520  174.31        0.664830
# 2010-01-11   30.015684  30.270   20.95   130.308  171.56       -0.882159
# ...                ...     ...     ...       ...     ...             ...
# 2018-06-25  182.170000  98.390   50.71  1663.150  221.54       -1.487130
# 2018-06-26  184.430000  99.080   49.67  1691.090  221.58        1.240599
# 2018-06-27  184.160000  97.540   48.76  1660.510  220.18       -0.146397
# 2018-06-28  185.500000  98.630   49.25  1701.450  223.42        0.727628
# 2018-06-29  185.110000  98.610   49.71  1699.800  220.57       -0.210243
#
#             Returns MSFT.O  Returns INTC.O  Returns AMZN.O  Returns GS.N
# Date
# 2010-01-05        0.032310       -0.047893        0.589993      1.767969
# 2010-01-06       -0.613695       -0.335410       -1.811567     -1.067333
# 2010-01-07       -1.033474       -0.961538       -1.701323      1.956846
# 2010-01-08        0.683042        1.116505        2.707692     -1.891147
# 2010-01-11       -1.272016        0.576092       -2.405632     -1.577649
# ...                    ...             ...             ...           ...
# 2018-06-25       -2.011752       -3.409524       -3.061195     -1.982125
# 2018-06-26        0.701291       -2.050878        1.679945      0.018055
# 2018-06-27       -1.554300       -1.832092       -1.808301     -0.631826
# 2018-06-28        1.117490        1.004922        2.465508      1.471523
# 2018-06-29       -0.020278        0.934010       -0.096976     -1.275624
#
# [2137 rows x 10 columns]

# %%
#read the fama data collected from the website

#website for fama french data: https://mba.tuck.dartmouth.edu/pages/faculty/ken.french/data_library.html

#data collected under fama french 3 factors [daily]

#original data was manually edited as there was parsing issues

fama = pd.read_csv('fama.csv')
fama['Date'] = fama['Date'].apply(lambda x: pd.to_datetime(str(x), format='%Y%m%d'))
fama.index = pd.to_datetime(fama['Date'])

# %%
data = pd.merge(tr, fama, left_index=True, right_index=True)
data
# Out:
#                 AAPL.O  MSFT.O  INTC.O    AMZN.O    GS.N  Returns AAPL.O  \
# Date
# 2010-01-05   30.625684  30.960   20.87   134.690  176.14        0.172889
# 2010-01-06   30.138541  30.770   20.80   132.250  174.26       -1.590633
# 2010-01-07   30.082827  30.452   20.60   130.000  177.67       -0.184860
# 2010-01-08   30.282827  30.660   20.83   133.520  174.31        0.664830
# 2010-01-11   30.015684  30.270   20.95   130.308  171.56       -0.882159
# ...                ...     ...     ...       ...     ...             ...
# 2018-06-25  182.170000  98.390   50.71  1663.150  221.54       -1.487130
# 2018-06-26  184.430000  99.080   49.67  1691.090  221.58        1.240599
# 2018-06-27  184.160000  97.540   48.76  1660.510  220.18       -0.146397
# 2018-06-28  185.500000  98.630   49.25  1701.450  223.42        0.727628
# 2018-06-29  185.110000  98.610   49.71  1699.800  220.57       -0.210243
#
#             Returns MSFT.O  Returns INTC.O  Returns AMZN.O  Returns GS.N  \
# Date
# 2010-01-05        0.032310       -0.047893        0.589993      1.767969
# 2010-01-06       -0.613695       -0.335410       -1.811567     -1.067333
# 2010-01-07       -1.033474       -0.961538       -1.701323      1.956846
# 2010-01-08        0.683042        1.116505        2.707692     -1.891147
# 2010-01-11       -1.272016        0.576092       -2.405632     -1.577649
# ...                    ...             ...             ...           ...
# 2018-06-25       -2.011752       -3.409524       -3.061195     -1.982125
# 2018-06-26        0.701291       -2.050878        1.679945      0.018055
# 2018-06-27       -1.554300       -1.832092       -1.808301     -0.631826
# 2018-06-28        1.117490        1.004922        2.465508      1.471523
# 2018-06-29       -0.020278        0.934010       -0.096976     -1.275624
#
#                  Date  Mkt-RF   SMB   HML     RF
# Date
# 2010-01-05 2010-01-05    0.31 -0.64  1.24  0.000
# 2010-01-06 2010-01-06    0.13 -0.22  0.57  0.000
# 2010-01-07 2010-01-07    0.40  0.09  0.98  0.000
# 2010-01-08 2010-01-08    0.33  0.37  0.01  0.000
# 2010-01-11 2010-01-11    0.13 -0.13 -0.25  0.000
# ...               ...     ...   ...   ...    ...
# 2018-06-25 2018-06-25   -1.48 -0.54  0.57  0.006
# 2018-06-26 2018-06-26    0.27  0.63 -0.24  0.006
# 2018-06-27 2018-06-27   -1.02 -1.00  0.36  0.006
# 2018-06-28 2018-06-28    0.58 -0.18 -0.51  0.006
# 2018-06-29 2018-06-29    0.07 -0.20 -0.24  0.006
#
# [2137 rows x 15 columns]

# %%
#generate directions for each stock
for col in store.columns:
    data[col + ' direction'] = np.sign(data['Returns' + ' ' + col])
    
data
# Out:
#                 AAPL.O  MSFT.O  INTC.O    AMZN.O    GS.N  Returns AAPL.O  \
# Date
# 2010-01-05   30.625684  30.960   20.87   134.690  176.14        0.172889
# 2010-01-06   30.138541  30.770   20.80   132.250  174.26       -1.590633
# 2010-01-07   30.082827  30.452   20.60   130.000  177.67       -0.184860
# 2010-01-08   30.282827  30.660   20.83   133.520  174.31        0.664830
# 2010-01-11   30.015684  30.270   20.95   130.308  171.56       -0.882159
# ...                ...     ...     ...       ...     ...             ...
# 2018-06-25  182.170000  98.390   50.71  1663.150  221.54       -1.487130
# 2018-06-26  184.430000  99.080   49.67  1691.090  221.58        1.240599
# 2018-06-27  184.160000  97.540   48.76  1660.510  220.18       -0.146397
# 2018-06-28  185.500000  98.630   49.25  1701.450  223.42        0.727628
# 2018-06-29  185.110000  98.610   49.71  1699.800  220.57       -0.210243
#
#             Returns MSFT.O  Returns INTC.O  Returns AMZN.O  Returns GS.N  \
# Date
# 2010-01-05        0.032310       -0.047893        0.589993      1.767969
# 2010-01-06       -0.613695       -0.335410       -1.811567     -1.067333
# 2010-01-07       -1.033474       -0.961538       -1.701323      1.956846
# 2010-01-08        0.683042        1.116505        2.707692     -1.891147
# 2010-01-11       -1.272016        0.576092       -2.405632     -1.577649
# ...                    ...             ...             ...           ...
# 2018-06-25       -2.011752       -3.409524       -3.061195     -1.982125
# 2018-06-26        0.701291       -2.050878        1.679945      0.018055
# 2018-06-27       -1.554300       -1.832092       -1.808301     -0.631826
# 2018-06-28        1.117490        1.004922        2.465508      1.471523
# 2018-06-29       -0.020278        0.934010       -0.096976     -1.275624
#
#                  Date  Mkt-RF   SMB   HML     RF  AAPL.O direction  \
# Date
# 2010-01-05 2010-01-05    0.31 -0.64  1.24  0.000               1.0
# 2010-01-06 2010-01-06    0.13 -0.22  0.57  0.000              -1.0
# 2010-01-07 2010-01-07    0.40  0.09  0.98  0.000              -1.0
# 2010-01-08 2010-01-08    0.33  0.37  0.01  0.000               1.0
# 2010-01-11 2010-01-11    0.13 -0.13 -0.25  0.000              -1.0
# ...               ...     ...   ...   ...    ...               ...
# 2018-06-25 2018-06-25   -1.48 -0.54  0.57  0.006              -1.0
# 2018-06-26 2018-06-26    0.27  0.63 -0.24  0.006               1.0
# 2018-06-27 2018-06-27   -1.02 -1.00  0.36  0.006              -1.0
# 2018-06-28 2018-06-28    0.58 -0.18 -0.51  0.006               1.0
# 2018-06-29 2018-06-29    0.07 -0.20 -0.24  0.006              -1.0
#
#             MSFT.O direction  INTC.O direction  AMZN.O direction  \
# Date
# 2010-01-05               1.0              -1.0               1.0
# 2010-01-06              -1.0              -1.0              -1.0
# 2010-01-07              -1.0              -1.0              -1.0
# 2010-01-08               1.0               1.0               1.0
# 2010-01-11              -1.0               1.0              -1.0
# ...                      ...               ...               ...
# 2018-06-25              -1.0              -1.0              -1.0
# 2018-06-26               1.0              -1.0               1.0
# 2018-06-27              -1.0              -1.0              -1.0
# 2018-06-28               1.0               1.0               1.0
# 2018-06-29              -1.0               1.0              -1.0
#
#             GS.N direction
# Date
# 2010-01-05             1.0
# 2010-01-06            -1.0
# 2010-01-07             1.0
# 2010-01-08            -1.0
# 2010-01-11            -1.0
# ...                    ...
# 2018-06-25            -1.0
# 2018-06-26             1.0
# 2018-06-27            -1.0
# 2018-06-28             1.0
# 2018-06-29            -1.0
#
# [2137 rows x 20 columns]

# %%
data.drop(columns = ['Date'])
# Out:
#                 AAPL.O  MSFT.O  INTC.O    AMZN.O    GS.N  Returns AAPL.O  \
# Date
# 2010-01-05   30.625684  30.960   20.87   134.690  176.14        0.172889
# 2010-01-06   30.138541  30.770   20.80   132.250  174.26       -1.590633
# 2010-01-07   30.082827  30.452   20.60   130.000  177.67       -0.184860
# 2010-01-08   30.282827  30.660   20.83   133.520  174.31        0.664830
# 2010-01-11   30.015684  30.270   20.95   130.308  171.56       -0.882159
# ...                ...     ...     ...       ...     ...             ...
# 2018-06-25  182.170000  98.390   50.71  1663.150  221.54       -1.487130
# 2018-06-26  184.430000  99.080   49.67  1691.090  221.58        1.240599
# 2018-06-27  184.160000  97.540   48.76  1660.510  220.18       -0.146397
# 2018-06-28  185.500000  98.630   49.25  1701.450  223.42        0.727628
# 2018-06-29  185.110000  98.610   49.71  1699.800  220.57       -0.210243
#
#             Returns MSFT.O  Returns INTC.O  Returns AMZN.O  Returns GS.N  \
# Date
# 2010-01-05        0.032310       -0.047893        0.589993      1.767969
# 2010-01-06       -0.613695       -0.335410       -1.811567     -1.067333
# 2010-01-07       -1.033474       -0.961538       -1.701323      1.956846
# 2010-01-08        0.683042        1.116505        2.707692     -1.891147
# 2010-01-11       -1.272016        0.576092       -2.405632     -1.577649
# ...                    ...             ...             ...           ...
# 2018-06-25       -2.011752       -3.409524       -3.061195     -1.982125
# 2018-06-26        0.701291       -2.050878        1.679945      0.018055
# 2018-06-27       -1.554300       -1.832092       -1.808301     -0.631826
# 2018-06-28        1.117490        1.004922        2.465508      1.471523
# 2018-06-29       -0.020278        0.934010       -0.096976     -1.275624
#
#             Mkt-RF   SMB   HML     RF  AAPL.O direction  MSFT.O direction  \
# Date
# 2010-01-05    0.31 -0.64  1.24  0.000               1.0               1.0
# 2010-01-06    0.13 -0.22  0.57  0.000              -1.0              -1.0
# 2010-01-07    0.40  0.09  0.98  0.000              -1.0              -1.0
# 2010-01-08    0.33  0.37  0.01  0.000               1.0               1.0
# 2010-01-11    0.13 -0.13 -0.25  0.000              -1.0              -1.0
# ...            ...   ...   ...    ...               ...               ...
# 2018-06-25   -1.48 -0.54  0.57  0.006              -1.0              -1.0
# 2018-06-26    0.27  0.63 -0.24  0.006               1.0               1.0
# 2018-06-27   -1.02 -1.00  0.36  0.006              -1.0              -1.0
# 2018-06-28    0.58 -0.18 -0.51  0.006               1.0               1.0
# 2018-06-29    0.07 -0.20 -0.24  0.006              -1.0              -1.0
#
#             INTC.O direction  AMZN.O direction  GS.N direction
# Date
# 2010-01-05              -1.0               1.0             1.0
# 2010-01-06              -1.0              -1.0            -1.0
# 2010-01-07              -1.0              -1.0             1.0
# 2010-01-08               1.0               1.0            -1.0
# 2010-01-11               1.0              -1.0            -1.0
# ...                      ...               ...             ...
# 2018-06-25              -1.0              -1.0            -1.0
# 2018-06-26              -1.0               1.0             1.0
# 2018-06-27              -1.0              -1.0            -1.0
# 2018-06-28               1.0               1.0             1.0
# 2018-06-29               1.0              -1.0            -1.0
#
# [2137 rows x 19 columns]

# %%
#get relevant data for ml
data = data.iloc[:, 5:]

data
# Out:
#             Returns AAPL.O  Returns MSFT.O  Returns INTC.O  Returns AMZN.O  \
# Date
# 2010-01-05        0.172889        0.032310       -0.047893        0.589993
# 2010-01-06       -1.590633       -0.613695       -0.335410       -1.811567
# 2010-01-07       -0.184860       -1.033474       -0.961538       -1.701323
# 2010-01-08        0.664830        0.683042        1.116505        2.707692
# 2010-01-11       -0.882159       -1.272016        0.576092       -2.405632
# ...                    ...             ...             ...             ...
# 2018-06-25       -1.487130       -2.011752       -3.409524       -3.061195
# 2018-06-26        1.240599        0.701291       -2.050878        1.679945
# 2018-06-27       -0.146397       -1.554300       -1.832092       -1.808301
# 2018-06-28        0.727628        1.117490        1.004922        2.465508
# 2018-06-29       -0.210243       -0.020278        0.934010       -0.096976
#
#             Returns GS.N       Date  Mkt-RF   SMB   HML     RF  \
# Date
# 2010-01-05      1.767969 2010-01-05    0.31 -0.64  1.24  0.000
# 2010-01-06     -1.067333 2010-01-06    0.13 -0.22  0.57  0.000
# 2010-01-07      1.956846 2010-01-07    0.40  0.09  0.98  0.000
# 2010-01-08     -1.891147 2010-01-08    0.33  0.37  0.01  0.000
# 2010-01-11     -1.577649 2010-01-11    0.13 -0.13 -0.25  0.000
# ...                  ...        ...     ...   ...   ...    ...
# 2018-06-25     -1.982125 2018-06-25   -1.48 -0.54  0.57  0.006
# 2018-06-26      0.018055 2018-06-26    0.27  0.63 -0.24  0.006
# 2018-06-27     -0.631826 2018-06-27   -1.02 -1.00  0.36  0.006
# 2018-06-28      1.471523 2018-06-28    0.58 -0.18 -0.51  0.006
# 2018-06-29     -1.275624 2018-06-29    0.07 -0.20 -0.24  0.006
#
#             AAPL.O direction  MSFT.O direction  INTC.O direction  \
# Date
# 2010-01-05               1.0               1.0              -1.0
# 2010-01-06              -1.0              -1.0              -1.0
# 2010-01-07              -1.0              -1.0              -1.0
# 2010-01-08               1.0               1.0               1.0
# 2010-01-11              -1.0              -1.0               1.0
# ...                      ...               ...               ...
# 2018-06-25              -1.0              -1.0              -1.0
# 2018-06-26               1.0               1.0              -1.0
# 2018-06-27              -1.0              -1.0              -1.0
# 2018-06-28               1.0               1.0               1.0
# 2018-06-29              -1.0              -1.0               1.0
#
#             AMZN.O direction  GS.N direction
# Date
# 2010-01-05               1.0             1.0
# 2010-01-06              -1.0            -1.0
# 2010-01-07              -1.0             1.0
# 2010-01-08               1.0            -1.0
# 2010-01-11              -1.0            -1.0
# ...                      ...             ...
# 2018-06-25              -1.0            -1.0
# 2018-06-26               1.0             1.0
# 2018-06-27              -1.0            -1.0
# 2018-06-28               1.0             1.0
# 2018-06-29              -1.0            -1.0
#
# [2137 rows x 15 columns]

# %%
#train test split 80/20
preddat = data.copy(deep = True)
split = int(0.8 * len(preddat))
data_train = preddat[: split]
data_test = preddat[split:]
preddat
# Out:
#             Returns AAPL.O  Returns MSFT.O  Returns INTC.O  Returns AMZN.O  \
# Date
# 2010-01-05        0.172889        0.032310       -0.047893        0.589993
# 2010-01-06       -1.590633       -0.613695       -0.335410       -1.811567
# 2010-01-07       -0.184860       -1.033474       -0.961538       -1.701323
# 2010-01-08        0.664830        0.683042        1.116505        2.707692
# 2010-01-11       -0.882159       -1.272016        0.576092       -2.405632
# ...                    ...             ...             ...             ...
# 2018-06-25       -1.487130       -2.011752       -3.409524       -3.061195
# 2018-06-26        1.240599        0.701291       -2.050878        1.679945
# 2018-06-27       -0.146397       -1.554300       -1.832092       -1.808301
# 2018-06-28        0.727628        1.117490        1.004922        2.465508
# 2018-06-29       -0.210243       -0.020278        0.934010       -0.096976
#
#             Returns GS.N       Date  Mkt-RF   SMB   HML     RF  \
# Date
# 2010-01-05      1.767969 2010-01-05    0.31 -0.64  1.24  0.000
# 2010-01-06     -1.067333 2010-01-06    0.13 -0.22  0.57  0.000
# 2010-01-07      1.956846 2010-01-07    0.40  0.09  0.98  0.000
# 2010-01-08     -1.891147 2010-01-08    0.33  0.37  0.01  0.000
# 2010-01-11     -1.577649 2010-01-11    0.13 -0.13 -0.25  0.000
# ...                  ...        ...     ...   ...   ...    ...
# 2018-06-25     -1.982125 2018-06-25   -1.48 -0.54  0.57  0.006
# 2018-06-26      0.018055 2018-06-26    0.27  0.63 -0.24  0.006
# 2018-06-27     -0.631826 2018-06-27   -1.02 -1.00  0.36  0.006
# 2018-06-28      1.471523 2018-06-28    0.58 -0.18 -0.51  0.006
# 2018-06-29     -1.275624 2018-06-29    0.07 -0.20 -0.24  0.006
#
#             AAPL.O direction  MSFT.O direction  INTC.O direction  \
# Date
# 2010-01-05               1.0               1.0              -1.0
# 2010-01-06              -1.0              -1.0              -1.0
# 2010-01-07              -1.0              -1.0              -1.0
# 2010-01-08               1.0               1.0               1.0
# 2010-01-11              -1.0              -1.0               1.0
# ...                      ...               ...               ...
# 2018-06-25              -1.0              -1.0              -1.0
# 2018-06-26               1.0               1.0              -1.0
# 2018-06-27              -1.0              -1.0              -1.0
# 2018-06-28               1.0               1.0               1.0
# 2018-06-29              -1.0              -1.0               1.0
#
#             AMZN.O direction  GS.N direction
# Date
# 2010-01-05               1.0             1.0
# 2010-01-06              -1.0            -1.0
# 2010-01-07              -1.0             1.0
# 2010-01-08               1.0            -1.0
# 2010-01-11              -1.0            -1.0
# ...                      ...             ...
# 2018-06-25              -1.0            -1.0
# 2018-06-26               1.0             1.0
# 2018-06-27              -1.0            -1.0
# 2018-06-28               1.0             1.0
# 2018-06-29              -1.0            -1.0
#
# [2137 rows x 15 columns]

# %% [markdown]
# Possible strategies:
#
# 1) Buy when Predicted returns > Actual returns
# 2) Buy when predicted direction is up

# %%
model = LinearRegression()

#train, predict, generate signals
accuracy = []
for col in store.columns:
    pred_returns = model.fit(data_train[['Mkt-RF','SMB','HML']], data_train['Returns' + ' ' + col]).predict(data_test[['Mkt-RF','SMB','HML']])
    pred_direction = model.fit(data_train[['Mkt-RF','SMB','HML']], data_train[col + ' direction']).predict(data_test[['Mkt-RF','SMB','HML']])
    data_test['pred_returns ' + col] = pred_returns
    data_test['pred_direc ' + col] = np.sign(pred_direction)
    data_test['Buy ' + col] = np.where((data_test['pred_returns ' + col] > data_test['Returns' + ' ' + col]),1,-1)
# Out:
# /var/folders/b1/75hldj_562lcklhvybmwbbz80000gn/T/ipykernel_55745/2303096008.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['pred_returns ' + col] = pred_returns
# /var/folders/b1/75hldj_562lcklhvybmwbbz80000gn/T/ipykernel_55745/2303096008.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['pred_direc ' + col] = np.sign(pred_direction)
# /var/folders/b1/75hldj_562lcklhvybmwbbz80000gn/T/ipykernel_55745/2303096008.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['Buy ' + col] = np.where((data_test['pred_returns ' + col] > data_test['Returns' + ' ' + col]),1,-1)
# /var/folders/b1/75hldj_562lcklhvybmwbbz80000gn/T/ipykernel_55745/2303096008.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['pred_returns ' + col] = pred_returns
# /var/folders/b1/75hldj_562lcklhvybmwbbz80000gn/T/ipykernel_55745/2303096008.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['pred_direc ' + col] = np.sign(pred_direction)
# /var/folders/b1/75hldj_562lcklhvybmwbbz80000gn/T/ipykernel_55745/2303096008.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['Buy ' + col] = np.where((data_test['pred_returns ' + col] > data_test['Returns' + ' ' + col]),1,-1)
# /var/folders/b1/75hldj_562lcklhvybmwbbz80000gn/T/ipykernel_55745/2303096008.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['pred_returns ' + col] = pred_returns
# /var/folders/b1/75hldj_562lcklhvybmwbbz80000gn/T/ipykernel_55745/2303096008.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['pred_direc ' + col] = np.sign(pred_direction)
# /var/folders/b1/75hldj_562lcklhvybmwbbz80000gn/T/ipykernel_55745/2303096008.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['Buy ' + col] = np.where((data_test['pred_returns ' + col] > data_test['Returns' + ' ' + col]),1,-1)
# /var/folders/b1/75hldj_562lcklhvybmwbbz80000gn/T/ipykernel_55745/2303096008.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['pred_returns ' + col] = pred_returns
# /var/folders/b1/75hldj_562lcklhvybmwbbz80000gn/T/ipykernel_55745/2303096008.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['pred_direc ' + col] = np.sign(pred_direction)
# /var/folders/b1/75hldj_562lcklhvybmwbbz80000gn/T/ipykernel_55745/2303096008.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['Buy ' + col] = np.where((data_test['pred_returns ' + col] > data_test['Returns' + ' ' + col]),1,-1)
# /var/folders/b1/75hldj_562lcklhvybmwbbz80000gn/T/ipykernel_55745/2303096008.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['pred_returns ' + col] = pred_returns
# /var/folders/b1/75hldj_562lcklhvybmwbbz80000gn/T/ipykernel_55745/2303096008.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['pred_direc ' + col] = np.sign(pred_direction)
# /var/folders/b1/75hldj_562lcklhvybmwbbz80000gn/T/ipykernel_55745/2303096008.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_test['Buy ' + col] = np.where((data_test['pred_returns ' + col] > data_test['Returns' + ' ' + col]),1,-1)

# %%
data_test
# Out:
#             Returns AAPL.O  Returns MSFT.O  Returns INTC.O  Returns AMZN.O  \
# Date
# 2016-10-18       -0.068056        0.768962        1.233575        0.578141
# 2016-10-19       -0.297948       -0.225460       -5.933775        0.004892
# 2016-10-20       -0.051230       -0.486703       -0.225289       -0.901320
# 2016-10-21       -0.392961        4.209607       -0.790291        1.069948
# 2016-10-24        0.900515        2.246061        0.312945        2.332141
# ...                    ...             ...             ...             ...
# 2018-06-25       -1.487130       -2.011752       -3.409524       -3.061195
# 2018-06-26        1.240599        0.701291       -2.050878        1.679945
# 2018-06-27       -0.146397       -1.554300       -1.832092       -1.808301
# 2018-06-28        0.727628        1.117490        1.004922        2.465508
# 2018-06-29       -0.210243       -0.020278        0.934010       -0.096976
#
#             Returns GS.N       Date  Mkt-RF   SMB   HML     RF  ...  \
# Date                                                            ...
# 2016-10-18      2.147929 2016-10-18    0.60 -0.17  0.05  0.001  ...
# 2016-10-19      1.089034 2016-10-19    0.25  0.04  0.94  0.001  ...
# 2016-10-20      0.000000 2016-10-20   -0.16 -0.03 -0.11  0.001  ...
# 2016-10-21      0.091685 2016-10-21    0.02 -0.14 -0.33  0.001  ...
# 2016-10-24      0.257629 2016-10-24    0.54  0.06 -0.19  0.001  ...
# ...                  ...        ...     ...   ...   ...    ...  ...
# 2018-06-25     -1.982125 2018-06-25   -1.48 -0.54  0.57  0.006  ...
# 2018-06-26      0.018055 2018-06-26    0.27  0.63 -0.24  0.006  ...
# 2018-06-27     -0.631826 2018-06-27   -1.02 -1.00  0.36  0.006  ...
# 2018-06-28      1.471523 2018-06-28    0.58 -0.18 -0.51  0.006  ...
# 2018-06-29     -1.275624 2018-06-29    0.07 -0.20 -0.24  0.006  ...
#
#             Buy MSFT.O  pred_returns INTC.O  pred_direc INTC.O  Buy INTC.O  \
# Date
# 2016-10-18          -1             0.634249                1.0          -1
# 2016-10-19           1             0.129919                1.0           1
# 2016-10-20           1            -0.148549               -1.0           1
# 2016-10-21          -1             0.083637                1.0           1
# 2016-10-24          -1             0.550939                1.0           1
# ...                ...                  ...                ...         ...
# 2018-06-25           1            -1.454576               -1.0           1
# 2018-06-26          -1             0.158155                1.0           1
# 2018-06-27           1            -0.862976               -1.0           1
# 2018-06-28          -1             0.681224                1.0          -1
# 2018-06-29           1             0.137021                1.0          -1
#
#             pred_returns AMZN.O  pred_direc AMZN.O  Buy AMZN.O  \
# Date
# 2016-10-18             0.756378                1.0           1
# 2016-10-19            -0.499233               -1.0          -1
# 2016-10-20            -0.026189               -1.0           1
# 2016-10-21             0.402653                1.0          -1
# 2016-10-24             0.879581                1.0          -1
# ...                         ...                ...         ...
# 2018-06-25            -2.182248               -1.0           1
# 2018-06-26             0.541436                1.0          -1
# 2018-06-27            -1.389483               -1.0           1
# 2018-06-28             1.244813                1.0          -1
# 2018-06-29             0.386813                1.0           1
#
#             pred_returns GS.N  pred_direc GS.N  Buy GS.N
# Date
# 2016-10-18           0.701248              1.0        -1
# 2016-10-19           1.210359              1.0         1
# 2016-10-20          -0.329233             -1.0        -1
# 2016-10-21          -0.345216             -1.0        -1
# 2016-10-24           0.366419              1.0         1
# ...                       ...              ...       ...
# 2018-06-25          -1.065426             -1.0         1
# 2018-06-26          -0.036539              1.0        -1
# 2018-06-27          -0.727143             -1.0        -1
# 2018-06-28           0.100878              1.0        -1
# 2018-06-29          -0.190996             -1.0         1
#
# [428 rows x 30 columns]

# %%
#Might be useful for analysis
#Statistical summary of regression of training data against returns
X = sm.add_constant(data_train[["Mkt-RF", "SMB", "HML"]])

for col in store.columns:
    y = data_train['Returns' + ' ' + col]
    model = sm.OLS(y, X).fit()
    print('Model summary for ' + col + '\n')
    print(model.summary())
    print('\n')
# Out:
# Model summary for AAPL.O
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Returns AAPL.O   R-squared:                       0.338
# Model:                            OLS   Adj. R-squared:                  0.337
# Method:                 Least Squares   F-statistic:                     289.8
# Date:                Mon, 01 Apr 2024   Prob (F-statistic):          5.27e-152
# Time:                        19:27:58   Log-Likelihood:                -2945.5
# No. Observations:                1709   AIC:                             5899.
# Df Residuals:                    1705   BIC:                             5921.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0400      0.033      1.215      0.224      -0.025       0.104
# Mkt-RF         1.0126      0.036     27.823      0.000       0.941       1.084
# SMB           -0.1609      0.069     -2.348      0.019      -0.295      -0.027
# HML           -0.6124      0.073     -8.435      0.000      -0.755      -0.470
# ==============================================================================
# Omnibus:                      287.694   Durbin-Watson:                   1.897
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4186.441
# Skew:                          -0.299   Prob(JB):                         0.00
# Kurtosis:                      10.644   Cond. No.                         2.55
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Model summary for MSFT.O
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Returns MSFT.O   R-squared:                       0.446
# Model:                            OLS   Adj. R-squared:                  0.445
# Method:                 Least Squares   F-statistic:                     458.1
# Date:                Mon, 01 Apr 2024   Prob (F-statistic):          2.98e-218
# Time:                        19:27:58   Log-Likelihood:                -2574.9
# No. Observations:                1709   AIC:                             5158.
# Df Residuals:                    1705   BIC:                             5179.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0061      0.026     -0.230      0.818      -0.058       0.046
# Mkt-RF         1.0519      0.029     35.900      0.000       0.994       1.109
# SMB           -0.3823      0.055     -6.931      0.000      -0.491      -0.274
# HML           -0.3559      0.058     -6.088      0.000      -0.471      -0.241
# ==============================================================================
# Omnibus:                      421.322   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22620.639
# Skew:                           0.180   Prob(JB):                         0.00
# Kurtosis:                      20.820   Cond. No.                         2.55
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Model summary for INTC.O
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Returns INTC.O   R-squared:                       0.438
# Model:                            OLS   Adj. R-squared:                  0.437
# Method:                 Least Squares   F-statistic:                     443.1
# Date:                Mon, 01 Apr 2024   Prob (F-statistic):          8.30e-213
# Time:                        19:27:58   Log-Likelihood:                -2606.4
# No. Observations:                1709   AIC:                             5221.
# Df Residuals:                    1705   BIC:                             5243.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0056      0.027     -0.209      0.835      -0.059       0.047
# Mkt-RF         1.0141      0.030     33.979      0.000       0.956       1.073
# SMB           -0.2189      0.056     -3.896      0.000      -0.329      -0.109
# HML           -0.1162      0.060     -1.951      0.051      -0.233       0.001
# ==============================================================================
# Omnibus:                      259.420   Durbin-Watson:                   2.065
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3579.102
# Skew:                           0.180   Prob(JB):                         0.00
# Kurtosis:                      10.080   Cond. No.                         2.55
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Model summary for AMZN.O
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Returns AMZN.O   R-squared:                       0.328
# Model:                            OLS   Adj. R-squared:                  0.326
# Method:                 Least Squares   F-statistic:                     276.8
# Date:                Mon, 01 Apr 2024   Prob (F-statistic):          2.34e-146
# Time:                        19:27:58   Log-Likelihood:                -3311.8
# No. Observations:                1709   AIC:                             6632.
# Df Residuals:                    1705   BIC:                             6653.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0627      0.041      1.538      0.124      -0.017       0.143
# Mkt-RF         1.2029      0.045     26.674      0.000       1.114       1.291
# SMB           -0.1036      0.085     -1.220      0.223      -0.270       0.063
# HML           -0.9133      0.090    -10.152      0.000      -1.090      -0.737
# ==============================================================================
# Omnibus:                      586.100   Durbin-Watson:                   2.037
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            24622.331
# Skew:                           0.877   Prob(JB):                         0.00
# Kurtosis:                      21.512   Cond. No.                         2.55
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Model summary for GS.N
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Returns GS.N   R-squared:                       0.609
# Model:                            OLS   Adj. R-squared:                  0.608
# Method:                 Least Squares   F-statistic:                     884.3
# Date:                Mon, 01 Apr 2024   Prob (F-statistic):               0.00
# Time:                        19:27:58   Log-Likelihood:                -2544.6
# No. Observations:                1709   AIC:                             5097.
# Df Residuals:                    1705   BIC:                             5119.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0384      0.026     -1.478      0.140      -0.089       0.013
# Mkt-RF         1.1228      0.029     39.003      0.000       1.066       1.179
# SMB           -0.0845      0.054     -1.558      0.119      -0.191       0.022
# HML            1.0335      0.057     17.996      0.000       0.921       1.146
# ==============================================================================
# Omnibus:                      264.034   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3196.729
# Skew:                          -0.292   Prob(JB):                         0.00
# Kurtosis:                       9.675   Cond. No.                         2.55
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# F-statistics for GS.N is questionable
