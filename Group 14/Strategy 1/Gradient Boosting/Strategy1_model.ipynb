# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import roc_auc_score, f1_score, precision_score, recall_score, classification_report
from sklearn import svm
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Models

# %% [markdown]
# ## Apple

# %%
# Apple
X_train_AAPL = pd.read_csv('data/AAPL/X_train_AAPL.csv', index_col=0)
y_train_AAPL = pd.read_csv('data/AAPL/y_train_AAPL.csv', index_col=0)
X_test_AAPL = pd.read_csv('data/AAPL/X_test_AAPL.csv', index_col=0)
y_test_AAPL = pd.read_csv('data/AAPL/y_test_AAPL.csv', index_col=0)

# %%
# Scale
scaler = MinMaxScaler()
X_train_AAPL = scaler.fit_transform(X_train_AAPL)
X_test_AAPL = scaler.transform(X_test_AAPL)

# %%
# model
apple =  HistGradientBoostingClassifier(random_state=42, max_depth=7, learning_rate=0.01, max_iter=100, min_samples_leaf=1, l2_regularization=0.1)
apple.fit(X_train_AAPL, y_train_AAPL.values.ravel())
# Out:
# HistGradientBoostingClassifier(l2_regularization=0.1, learning_rate=0.01,
#                                max_depth=7, min_samples_leaf=1,
#                                random_state=42)

# %%
apple.score(X_train_AAPL, y_train_AAPL)
# Out:
# 0.8194038573933372

# %%
apple.score(X_test_AAPL, y_test_AAPL)
# Out:
# 0.4964871194379391

# %%
print(classification_report(y_test_AAPL, apple.predict(X_test_AAPL)))
roc_auc_score(y_test_AAPL, apple.predict(X_test_AAPL))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.47      0.77      0.59       203
#            1       0.52      0.22      0.31       224
#
#     accuracy                           0.48       427
#    macro avg       0.49      0.50      0.45       427
# weighted avg       0.50      0.48      0.44       427
# 0.4960745073891626

# %%
prob_AAPL = pd.DataFrame(apple.predict_proba(X_test_AAPL))
pred_AAPL = pd.DataFrame(apple.predict(X_test_AAPL))

# %%
pd.DataFrame(classification_report(y_test_AAPL, apple.predict(X_test_AAPL), output_dict=True)).transpose().to_csv('data/AAPL/classification_report.csv')

# %% [markdown]
# ## Amazon

# %%
X_train_AMZN = pd.read_csv('data/AMZN/X_train_AMZN.csv', index_col=0)
y_train_AMZN = pd.read_csv('data/AMZN/y_train_AMZN.csv', index_col=0)
X_test_AMZN = pd.read_csv('data/AMZN/X_test_AMZN.csv', index_col=0)
y_test_AMZN = pd.read_csv('data/AMZN/y_test_AMZN.csv', index_col=0)

# %%
scaler = MinMaxScaler()
X_train_AMZN = scaler.fit_transform(X_train_AMZN)
X_test_AMZN = scaler.transform(X_test_AAPL)
# Out:
# c:\Users\Swifte\anaconda3\envs\QF2103\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
amazon =  HistGradientBoostingClassifier(random_state=42, max_depth=6, learning_rate=0.01, max_iter=100, min_samples_leaf=2, l2_regularization=1)
amazon.fit(X_train_AMZN, y_train_AMZN.values.ravel())
# Out:
# HistGradientBoostingClassifier(l2_regularization=1, learning_rate=0.01,
#                                max_depth=6, min_samples_leaf=2,
#                                random_state=42)

# %%
amazon.score(X_train_AMZN, y_train_AMZN)
# Out:
# 0.7042665108123904

# %%
print(classification_report(y_test_AMZN, amazon.predict(X_test_AMZN)))
roc_auc_score(y_test_AMZN, amazon.predict(X_test_AMZN))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       185
#            1       0.57      1.00      0.72       242
#
#     accuracy                           0.57       427
#    macro avg       0.28      0.50      0.36       427
# weighted avg       0.32      0.57      0.41       427
# c:\Users\Swifte\anaconda3\envs\QF2103\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Swifte\anaconda3\envs\QF2103\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Swifte\anaconda3\envs\QF2103\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 0.5

# %%
prob_AMZN = pd.DataFrame(amazon.predict_proba(X_test_AMZN))
pred_AMZN = pd.DataFrame(amazon.predict(X_test_AMZN))

# %%
pd.DataFrame(classification_report(y_test_AMZN, amazon.predict(X_test_AMZN), output_dict=True)).transpose().to_csv('data/AMZN/classification_report.csv')
# Out:
# c:\Users\Swifte\anaconda3\envs\QF2103\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Swifte\anaconda3\envs\QF2103\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Swifte\anaconda3\envs\QF2103\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## GS

# %%
X_train_GS = pd.read_csv('data/GS/X_train_GS.csv', index_col=0)
y_train_GS = pd.read_csv('data/GS/y_train_GS.csv', index_col=0)
X_test_GS = pd.read_csv('data/GS/X_test_GS.csv', index_col=0)
y_test_GS = pd.read_csv('data/GS/y_test_GS.csv', index_col=0)

# %%
scalar = MinMaxScaler()
X_train_GS = scalar.fit_transform(X_train_GS)
X_test_GS = scalar.transform(X_test_GS)

# %%
GS = HistGradientBoostingClassifier(random_state=42, max_depth=12, learning_rate=0.02, max_iter=100, min_samples_leaf=4, l2_regularization=0.1)
GS.fit(X_train_GS, y_train_GS.values.ravel())
# Out:
# HistGradientBoostingClassifier(l2_regularization=0.1, learning_rate=0.02,
#                                max_depth=12, min_samples_leaf=4,
#                                random_state=42)

# %%
print(classification_report(y_test_GS, GS.predict(X_test_GS)))
roc_auc_score(y_test_GS, GS.predict(X_test_GS))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.33      0.39       199
#            1       0.54      0.69      0.61       228
#
#     accuracy                           0.52       427
#    macro avg       0.51      0.51      0.50       427
# weighted avg       0.51      0.52      0.50       427
# 0.507614828528608

# %%
prob_GS = pd.DataFrame(GS.predict_proba(X_test_GS))   
pred_GS = GS.predict(X_test_GS)

# %%
pd.DataFrame(classification_report(y_test_GS, GS.predict(X_test_GS), output_dict=True)).transpose().to_csv('data/GS/classification_report.csv')

# %% [markdown]
# ## INTC

# %%
X_train_INTC = pd.read_csv('data/INTC/X_train_INTC.csv', index_col=0)
y_train_INTC = pd.read_csv('data/INTC/y_train_INTC.csv', index_col=0)
X_test_INTC = pd.read_csv('data/INTC/X_test_INTC.csv', index_col=0)
y_test_INTC = pd.read_csv('data/INTC/y_test_INTC.csv', index_col=0)

# %%
scalar = MinMaxScaler()
X_train_INTC = scalar.fit_transform(X_train_INTC)
X_test_INTC = scalar.transform(X_test_INTC)

# %%
INTC = HistGradientBoostingClassifier(random_state=42, max_depth=12, learning_rate=0.02, max_iter=100, min_samples_leaf=4, l2_regularization=0.1)
INTC.fit(X_train_INTC, y_train_INTC.values.ravel())
# Out:
# HistGradientBoostingClassifier(l2_regularization=0.1, learning_rate=0.02,
#                                max_depth=12, min_samples_leaf=4,
#                                random_state=42)

# %%
print(classification_report(y_test_INTC, INTC.predict(X_test_INTC)))
roc_auc_score(y_test_INTC, INTC.predict(X_test_INTC))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.46      0.61      0.52       198
#            1       0.52      0.37      0.43       229
#
#     accuracy                           0.48       427
#    macro avg       0.49      0.49      0.48       427
# weighted avg       0.49      0.48      0.48       427
# 0.49114507520621054

# %%
prob_INTC = pd.DataFrame(INTC.predict_proba(X_test_INTC))
pred_INTC = pd.DataFrame(INTC.predict(X_test_INTC))

# %%
pd.DataFrame(classification_report(y_test_GS, GS.predict(X_test_GS), output_dict=True)).transpose().to_csv('data/INTC/classification_report.csv')

# %% [markdown]
# ### MSFT

# %%
X_train_MSFT = pd.read_csv('data/MSFT/X_train_MSFT.csv', index_col=0)   
y_train_MSFT = pd.read_csv('data/MSFT/y_train_MSFT.csv', index_col=0)
X_test_MSFT = pd.read_csv('data/MSFT/X_test_MSFT.csv', index_col=0)
y_test_MSFT = pd.read_csv('data/MSFT/y_test_MSFT.csv', index_col=0)

# %%
scalar = MinMaxScaler()
X_train_MSFT = scalar.fit_transform(X_train_MSFT)
X_test_MSFT = scalar.transform(X_test_MSFT)

# %%
MSFT = HistGradientBoostingClassifier(random_state=42, max_depth=12, learning_rate=0.02, max_iter=100, min_samples_leaf=4, l2_regularization=0.1)
MSFT.fit(X_train_MSFT, y_train_MSFT.values.ravel())
# Out:
# HistGradientBoostingClassifier(l2_regularization=0.1, learning_rate=0.02,
#                                max_depth=12, min_samples_leaf=4,
#                                random_state=42)

# %%
print(classification_report(y_test_MSFT, MSFT.predict(X_test_MSFT)))
roc_auc_score(y_test_MSFT, MSFT.predict(X_test_MSFT))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.47      0.66      0.55       199
#            1       0.55      0.36      0.43       228
#
#     accuracy                           0.50       427
#    macro avg       0.51      0.51      0.49       427
# weighted avg       0.51      0.50      0.49       427
# 0.5092898704046548

# %%
prob_MSFT = MSFT.predict_proba(X_test_MSFT)
pred_MSFT = MSFT.predict(X_test_MSFT)

# %%
pd.DataFrame(classification_report(y_test_GS, GS.predict(X_test_GS), output_dict=True)).transpose().to_csv('data/MSFT/classification_report.csv')

# %% [markdown]
# # Backtest

# %%
# row wise profit
def single_side(row):
    if row['pred'] == 1:
        return row['Close'] - row['Open']
    else:
        return row['Open'] - row['Close']

# %%
# row wise log return
def single_side_logret(row):
    if row['pred'] == 1:
        return np.log(row['Close'] / row['Open'])
    else:
        return np.log(row['Open'] / row['Close'])

# %%
# inverted log return 
def inverted_single_side(row):
    if row['pred'] == 0:
        return np.log(row['Close'] / row['Open'])
    else:
        return np.log(row['Open'] / row['Close'])

# %%
# profit with conf cutoff - not used 
def single_side_with_prob_cutoff(row):
    if row['pred'] == 1 and row['prob1'] > 0.6:
        return row['Close'] - row['Open']
    elif row['pred'] == 0 and row['prob0'] > 0.6:
        return row['Open'] - row['Close']
    else:
        return 0

# %%
# row-wise long short
def long_short(row):
    return (row['Close'] - row['Open']) * row['prob1'] + (row['Open'] - row['Close']) * row['prob0']

# %%
# row-wise long short log return
def long_short_logret(row):
    return (np.log(row['Close'] / row['Open'])) * row['prob1'] + (np.log(row['Open'] / row['Close'])) * row['prob0']

# %%
# naive strategy 
def single(df):
    arr = []
    for index, row in df.iterrows():
        arr.append(single_side_logret(row))
    return np.array(arr).sum(), np.array(arr).std()

# %%
# inverted naive strategy
def inverted_single(df):
    arr = []
    for index, row in df.iterrows():
        arr.append(inverted_single_side(row))
    return np.array(arr).sum(), np.array(arr).std()

# %%
# Long short strategy
def LS(df):
    arr = []
    for index, row in df.iterrows():
        arr.append(long_short_logret(row))
    return np.array(arr).sum(), np.array(arr).std()

# %%
# dollar cost averaging
def dollar_cost_averaging(df, interval, capital):
    shares = 0
    capital_used = 0
    for index, row in df.iterrows():
        if index % interval == 0:
            shares += capital / row['Open']
            capital_used += capital

    
    return capital_used, shares, shares * df.iloc[-1]['Close']

# %%
# dca with volatility
def dca_vol(df, interval, capital):
    shares = 0
    capital_used = 0
    arr = []
    for index, row in df.iterrows():
        if index % interval == 0:
            shares += capital / row['Open']
            capital_used += capital
            arr.append(np.log(shares * row['Open'] / capital_used))
    

    
    return capital_used, shares, shares * df.iloc[-1]['Close'], np.std(arr), np.log(shares * df.iloc[-1]['Close'] / capital_used)

# %%
# buy and hold 
def buy_and_hold(df, interval, capital):
    shares = 0
    arr = []
    for index, row in df.iterrows():
        if index == 0:
            shares += capital / row['Open']
        elif index % interval == 0:
            arr.append(np.log(shares * row['Open'] / capital))

    
    return shares, shares * df.iloc[-1]['Close'], np.std(arr), np.log(shares * df.iloc[-1]['Close'] / capital)

# %% [markdown]
# ### MSFT

# %%
prob_MSFT = pd.DataFrame(prob_MSFT, columns=['prob_0', 'prob_1'])
prob_MSFT
# Out:
#        prob_0    prob_1
# 0    0.449876  0.550124
# 1    0.327562  0.672438
# 2    0.596223  0.403777
# 3    0.668389  0.331611
# 4    0.549018  0.450982
# ..        ...       ...
# 422  0.499714  0.500286
# 423  0.438293  0.561707
# 424  0.506107  0.493893
# 425  0.539444  0.460556
# 426  0.532281  0.467719
#
# [427 rows x 2 columns]

# %%
backtest_MSFT = pd.read_csv('data/MSFT/X_test_MSFT.csv')[['Open', 'Close']]
backtest_MSFT['pred'] = pred_MSFT
backtest_MSFT[['prob0', 'prob1']] = prob_MSFT
backtest_MSFT['single'] = backtest_MSFT.apply(single_side, axis=1)
backtest_MSFT['single_with_prob_cutoff'] = backtest_MSFT.apply(single_side_with_prob_cutoff, axis=1)
backtest_MSFT['cumsum'] = backtest_MSFT['single'].cumsum()
backtest_MSFT['cumsum_with_prob_cutoff'] = backtest_MSFT['single_with_prob_cutoff'].cumsum()
backtest_MSFT['long_short'] = backtest_MSFT.apply(long_short, axis=1)
backtest_MSFT['cumsum_long_short'] = backtest_MSFT['long_short'].cumsum()
backtest_MSFT
# Out:
#        Open  Close  pred     prob0     prob1  single  single_with_prob_cutoff  \
# 0     57.47  57.53     1  0.449876  0.550124    0.06                     0.00
# 1     57.50  57.25     1  0.327562  0.672438   -0.25                    -0.25
# 2     60.28  59.66     0  0.596223  0.403777    0.62                     0.00
# 3     59.94  61.00     0  0.668389  0.331611   -1.06                    -1.06
# 4     60.85  60.99     0  0.549018  0.450982   -0.14                     0.00
# ..      ...    ...   ...       ...       ...     ...                      ...
# 422  100.00  98.39     1  0.499714  0.500286   -1.61                     0.00
# 423   98.82  99.08     1  0.438293  0.561707    0.26                     0.00
# 424   99.58  97.54     0  0.506107  0.493893    2.04                     0.00
# 425   97.38  98.63     0  0.539444  0.460556   -1.25                     0.00
# 426   98.93  98.61     0  0.532281  0.467719    0.32                     0.00
#
#      cumsum  cumsum_with_prob_cutoff  long_short  cumsum_long_short
# 0      0.06                     0.00    0.006015           0.006015
# 1     -0.19                    -0.25   -0.086219          -0.080204
# 2      0.43                    -0.25    0.119317           0.039113
# 3     -0.63                    -1.31   -0.356986          -0.317873
# 4     -0.77                    -1.31   -0.013725          -0.331597
# ..      ...                      ...         ...                ...
# 422  -19.68                   -17.57   -0.000920          -5.877308
# 423  -19.42                   -17.57    0.032088          -5.845220
# 424  -17.38                   -17.57    0.024916          -5.820304
# 425  -18.63                   -17.57   -0.098611          -5.918915
# 426  -18.31                   -17.57    0.020660          -5.898255
#
# [427 rows x 11 columns]

# %%
dollar_cost_averaging(backtest_MSFT, 5, 100)
# Out:
# (8600, 114.62599847424194, 11303.269709544997)

# %%
dca_vol(backtest_MSFT, 5, 100)
# Out:
# (8600,
#  114.62599847424194,
#  11303.269709544997,
#  0.09925774293252033,
#  0.2733298354307894)

# %%
buy_and_hold(backtest_MSFT, 5, 42700)
# Out:
# (742.9963459196102, 73266.86967113276, 0.16618111726235682, 0.5399096038245876)

# %%
single(backtest_MSFT)
# Out:
# (-0.24178078579438161, 0.010526935915522312)

# %%
LS(backtest_MSFT)
# Out:
# (-0.07260055052670837, 0.0016219133135315937)

# %%
backtest_MSFT
# Out:
#        Open  Close  pred     prob0     prob1  single  single_with_prob_cutoff  \
# 0     57.47  57.53     1  0.449876  0.550124    0.06                     0.00
# 1     57.50  57.25     1  0.327562  0.672438   -0.25                    -0.25
# 2     60.28  59.66     0  0.596223  0.403777    0.62                     0.00
# 3     59.94  61.00     0  0.668389  0.331611   -1.06                    -1.06
# 4     60.85  60.99     0  0.549018  0.450982   -0.14                     0.00
# ..      ...    ...   ...       ...       ...     ...                      ...
# 422  100.00  98.39     1  0.499714  0.500286   -1.61                     0.00
# 423   98.82  99.08     1  0.438293  0.561707    0.26                     0.00
# 424   99.58  97.54     0  0.506107  0.493893    2.04                     0.00
# 425   97.38  98.63     0  0.539444  0.460556   -1.25                     0.00
# 426   98.93  98.61     0  0.532281  0.467719    0.32                     0.00
#
#      cumsum  cumsum_with_prob_cutoff  long_short  cumsum_long_short
# 0      0.06                     0.00    0.006015           0.006015
# 1     -0.19                    -0.25   -0.086219          -0.080204
# 2      0.43                    -0.25    0.119317           0.039113
# 3     -0.63                    -1.31   -0.356986          -0.317873
# 4     -0.77                    -1.31   -0.013725          -0.331597
# ..      ...                      ...         ...                ...
# 422  -19.68                   -17.57   -0.000920          -5.877308
# 423  -19.42                   -17.57    0.032088          -5.845220
# 424  -17.38                   -17.57    0.024916          -5.820304
# 425  -18.63                   -17.57   -0.098611          -5.918915
# 426  -18.31                   -17.57    0.020660          -5.898255
#
# [427 rows x 11 columns]

# %%
inverted_single(backtest_MSFT)
# Out:
# (0.2417807857943828, 0.010526935915522314)

# %% [markdown]
# ### INTC

# %%
backtest_INTC = pd.read_csv('data/INTC/X_test_INTC.csv')[['Open', 'Close']]
backtest_INTC['pred'] = pred_INTC
backtest_INTC[['prob0', 'prob1']] = prob_INTC

# %%
single(backtest_INTC)
# Out:
# (-0.11611172102569797, 0.012407051681920196)

# %%
LS(backtest_INTC)
# Out:
# (-0.01865539412623067, 0.004624049520409243)

# %%
dca_vol(backtest_INTC, 5, 100)
# Out:
# (8600,
#  214.01565686270413,
#  10638.718302645022,
#  0.12769129981230878,
#  0.21273781312039078)

# %%
buy_and_hold(backtest_INTC, 5, 8600)
# Out:
# (238.42528416967008, 11852.1208760743, 0.16271711971558886, 0.3207446251911336)

# %%
inverted_single(backtest_INTC)
# Out:
# (0.11611172102569668, 0.0124070516819202)

# %% [markdown]
# ### GS

# %%
backtest_GS = pd.read_csv('data/GS/X_test_GS.csv')[['Open', 'Close']]
backtest_GS['pred'] = pred_GS
backtest_GS[['prob0', 'prob1']] = prob_GS

# %%
single(backtest_GS)
# Out:
# (-0.46932300587197434, 0.012088290408560062)

# %%
LS(backtest_GS)
# Out:
# (-0.29121988523578574, 0.0045973392620061015)

# %%
dca_vol(backtest_GS, 5, 100)
# Out:
# (8600,
#  36.81430532514525,
#  8120.131325567288,
#  0.0628925157194115,
#  -0.057415876117238925)

# %%
buy_and_hold(backtest_GS, 5, 2200)
# Out:
# (12.689623348906961,
#  2798.9502220684085,
#  0.08115440722737256,
#  0.24078706582670018)

# %%
inverted_single(backtest_GS)
# Out:
# (0.469323005871975, 0.01208829040856006)

# %% [markdown]
# ### AMZN

# %%
backtest_AMZN = pd.read_csv('data/AMZN/X_test_AMZN.csv')[['Open', 'Close']]
backtest_AMZN['pred'] = pred_AMZN
backtest_AMZN[['prob0', 'prob1']] = prob_AMZN

# %%
single(backtest_AMZN)
# Out:
# (-0.15960108982086169, 0.01277850238555408)

# %%
LS(backtest_AMZN)
# Out:
# (-0.02331660925780254, 0.001827239586373414)

# %%
dca_vol(backtest_AMZN, 5, 100)
# Out:
# (8600,
#  8.296022609773102,
#  14101.57923209232,
#  0.16813515653990316,
#  0.49452459012892486)

# %%
buy_and_hold(backtest_AMZN, 5, 8600)
# Out:
# (10.482691370063383,
#  17818.47879083374,
#  0.24999789679932663,
#  0.7284738498663001)

# %%
inverted_single(backtest_AMZN)
# Out:
# (0.15960108982086146, 0.012778502385554077)

# %% [markdown]
# ### AAPL

# %%
backtest_AAPL = pd.read_csv('data/AAPL/X_test_AAPL.csv')[['Open', 'Close']]
backtest_AAPL['pred'] = pred_AAPL
backtest_AAPL[['prob0', 'prob1']] = prob_AAPL

# %%
single(backtest_AAPL)
# Out:
# (-0.21631300581948112, 0.010008155184946752)

# %%
LS(backtest_AAPL)
# Out:
# (-0.08469236182683482, 0.0012470750687455646)

# %%
dca_vol(backtest_AAPL, 5, 100)
# Out:
# (8600,
#  57.442943936222356,
#  10633.26335203412,
#  0.07387772252230494,
#  0.21222493652816465)

# %%
buy_and_hold(backtest_AAPL, 5, 8600)
# Out:
# (73.34754797441364,
#  13577.364605543711,
#  0.1566470550478078,
#  0.45664183564520516)

# %%
inverted_single(backtest_AAPL)
# Out:
# (0.21631300581947915, 0.010008155184946755)
